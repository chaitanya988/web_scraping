# %%
import time
import body as body
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
    

chrome_options = webdriver.ChromeOptions()
prefs = {'download.default_directory' : r'C:\NTPC\srldc'}
chrome_options.add_experimental_option('prefs', prefs)
#driver = webdriver.Chrome(chrome_options=chrome_option)
driver=webdriver.Chrome(ChromeDriverManager().install(),chrome_options=chrome_options)
driver.maximize_window()
driver.get("https://srldc.in/WBES_XML")
#startlink=1

wait = WebDriverWait(driver, 10)

time.sleep(3)

x=50 
for j in range(0,14):
    startlink=1
    driver.find_element_by_xpath("/html/body/div[2]/section/div/div/div[2]/div/div/div[1]/label/select").click()
    time.sleep(2)
    driver.find_element_by_xpath("/html/body/div[2]/section/div/div/div[2]/div/div/div[1]/label/select/option[4]").click()
    time.sleep(2)

    table=driver.find_elements_by_xpath("/html/body/div[2]/section/div/div/div[2]/div/div/table/tbody/tr")
    print(len(table))
    print("start")
    print(startlink)
        
    print("End")
    
    #print(len(countries))
    #print(len(countries))

    time.sleep(5)
    for i in range(startlink,len(table)):
        time.sleep(2)
        x+=30
        driver.execute_script(('window.scrollTo(0, {0});'.format(x)))
        time.sleep(2)
        xml=driver.find_element_by_xpath("/html/body/div[2]/section/div/div/div[2]/div/div/table/tbody/tr["+str(i)+"]/td[2]/a")
        time.sleep(3)
        xml.click()

        #driver.find_element_by_xpath("/html/body/div[3]/div/div[2]/div/div/div[1]/label/select/option[4]").click()
       # time.sleep(2)
        

        #download pdf invoice
        
    try:
        driver.find_element_by_xpath("/html/body/div[2]/section/div/div/div[2]/div/div/div[4]/a[2]").click()
        time.sleep(2)
    except:
        print("start_len:",startlink)
        break

# %% [markdown]
#     print("start")
#     print(startlink)
#
#     print("End")
#     print(len(countries))
#     #print(len(countries))
#
#     time.sleep(5)
#     x=100
#     for i in range(startlink,len(countries)+1):
#         time.sleep(5)
#         x+=30
#         driver.execute_script(('window.scrollTo(0, {0});'.format(x)))
#         time.sleep(10)
#         pdf_link=driver.find_element_by_xpath("/html/body/div[3]/div/div[2]/div/div/table/tbody/tr["+str(i)+"]/td[3]/div/ul/li/a")
#         driver.execute_script("arguments[0].setAttribute('download','')",pdf_link)
#         time.sleep(2)
#         pdf_link.click()
#         print(i)
#         time.sleep(5)
#     #startlink=len(countries)
#     try:
#         driver.find_element_by_xpath("/html/body/div[3]/div/div[2]/div/div/div[4]/a[2]").click()
#     except:
#         break
