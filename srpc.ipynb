# %%
import pandas as pd
import numpy as np
import zipfile

from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import bs4
from urllib.request import urlopen
from bs4 import BeautifulSoup

from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
from selenium.webdriver.support import expected_conditions as EC

# %%
chrome_options = webdriver.ChromeOptions()
prefs = {'download.default_directory' : 'E:\TestingFolder\srpc'}
chrome_options.add_experimental_option('prefs', prefs)
#driver = webdriver.Chrome(chrome_options=chrome_options)
driver=webdriver.Chrome(ChromeDriverManager().install(),chrome_options=chrome_options)
driver.maximize_window()
driver.get("http://www.srpc.kar.nic.in/html/xml-search/commercial.html#gsc.tab=0")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Acer\.wdm\drivers\chromedriver\win32\95.0.4638.69]
# <ipython-input-4-c6c92294c99f>:5: DeprecationWarning: use options instead of chrome_options
#   driver=webdriver.Chrome(ChromeDriverManager().install(),chrome_options=chrome_options)

# %%
sleep(5)
page_source = driver.page_source
soup1 = BeautifulSoup(page_source, 'lxml')
type(soup1)
bs4.BeautifulSoup
title = soup1.title

select_tag=soup1.find("select",{"id":"category"})
option_grop_tag=select_tag.find("optgroup")
option_tag=option_grop_tag.find_all("option")

print(len(option_tag))
# Out:
# 28

# %%
for i in range(0,len(option_tag)):
    text=driver.find_element_by_xpath("/html/body/div[1]/div[2]/label/select/optgroup/option["+str(i+1)+"]").click()
    sleep(3)
    page_source = driver.page_source
    soup2 = BeautifulSoup(page_source, 'lxml')
    type(soup2)
    bs4.BeautifulSoup
    tabel_tag=soup2.find("table",{"id":"grid"})
    th_tag=tabel_tag.find_all("th")
    tr_tag=tabel_tag.find_all("tr")
    for j in range(0,len(th_tag)):
        print(th_tag[j].text)
        if th_tag[j].text == "DataFile":
            td_tag = tabel_tag.find_all("td")
            for row in range(1,len(tr_tag)):
                try:
                    driver.find_element_by_xpath("/html/body/div[1]/div[3]/table/tbody/tr["+str(row)+"]/td["+str(j+1)+"]/a").click()
                except:
                    print("No file to download")
            print(j)
        elif th_tag[j].text == "Data File":
            td_tag = tabel_tag.find_all("td")
            for row in range(1,len(tr_tag)):
                try:
                    driver.find_element_by_xpath("/html/body/div[1]/div[3]/table/tbody/tr["+str(row)+"]/td["+str(j+1)+"]/a").click()
                except:
                    print("No file to download")
            print(j)
        else:
            print("no")
# Out:
# Period
# no
# Details
# no
#
# no
#
# no
#
# no
#
# no
#
# no
# Period
# no
# Certification
# no
# Annexures
# no
# DataFile
# 3
#
# no
#
# no
#
# no
# Period
# no
# Certification
# no
# Annexures
# no
# DataFile
# 3
#
# no
#
# no
#
# no
# Period
# no
# SCED
# no
# Datafile
# no
#
# no
#
# no
#
# no
#
# no
# Period
# no
# SCED
# no
# Datafile
# no
#
# no
#
# no
#
# no
#
# no
# Period
# no
# SCED
# no
# Datafile
# no
#
# no
#
# no
#
# no
#
# no
# Period
# no
# DSM
# no
# REAC
# no
# CONG
# no
# RRAS
# no
# SCED
# no
# Data File
# No file to download
# 6
# Period
# no
# DSM
# no
# REAC
# no
# CONG
# no
# RRAS
# no
# SCED
# no
# Data File
# No file to download
# 6
# Period
# no
# DSM
# no
# REAC
# no
# CONG
# no
# RRAS
# no
# SCED
# no
# Data File
# No file to download
# 6
# Period
# no
# Deviation Statement
# no
# Reactive Statement
# no
# Congestion Statement
# no
# Ancillary Statement
# no
# Data File
# No file to download
# No file to download
# 5
#
# no
# Period
# no
# ...

# %%
import os, zipfile

dir_name = 'E:\TestingFolder\srpc'
extension = ".zip"

os.chdir("E:\TestingFolder\srpc") #change directory from working dir to dir with files

for item in os.listdir(dir_name): # loop through items in dir
    if item.endswith(extension): # check for ".zip" extension
        file_name = os.path.abspath(item) # get full path of files
        #zip_ref = zipfile.ZipFile(file_name) # create zipfile object
        zip_ref=ZipFile(item,'r')
        zip_ref.extractall(dir_name) #extract file to dir
        zip_ref.close() #close file
        os.remove(file_name) #delete zipped file

# %%
from zipfile import ZipFile
zf = ZipFile('E://TestingFolder/13-26 Aug, 2018.zip', 'r')
zf.extractall('E:\TestingFolder')
zf.close()
