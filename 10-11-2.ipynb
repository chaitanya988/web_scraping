# %%
for i in range(1,len(table)):
    time.sleep(5)
    x+=30
    driver.execute_script(('window.scrollTo(0, {0});'.format(x)))
    time.sleep(10)
    pdf_link=driver.find_element_by_xpath("/html/body/form/div[3]/div/div[2]/div[2]/table/tbody/tr["+str(i)+"]/td[7]/a")
    betlad=driver.find_element_by_xpath("/html/body/form/div[3]/div/div[2]/div[2]/table/tbody/tr["+str(i)+"]/td[1]")
    print(betlad.text)
    print(pdf_link.text)
    if betlad.text=='Betald':
        driver.execute_script("arguments[0].setAttribute('download','')",pdf_link)
        time.sleep(2)
        pdf_link.click()
        print(i)
        time.sleep(5)

# %%
import pandas as pd
import numpy as np
import zipfile

from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import bs4
from urllib.request import urlopen
from bs4 import BeautifulSoup

from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
from selenium.webdriver.support import expected_conditions as EC

# %%
chrome_options = webdriver.ChromeOptions()
prefs = {'download.default_directory' : 'E:\\NTPC\WRLDC'}
chrome_options.add_experimental_option('prefs', prefs)
#driver = webdriver.Chrome(chrome_options=chrome_options)
driver=webdriver.Chrome(ChromeDriverManager().install(),chrome_options=chrome_options)
driver.maximize_window()
driver.get("https://wbes.wrldc.in:81/list.aspx")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Acer\.wdm\drivers\chromedriver\win32\95.0.4638.69]
# <ipython-input-2-568fd8da7c1e>:5: DeprecationWarning: use options instead of chrome_options
#   driver=webdriver.Chrome(ChromeDriverManager().install(),chrome_options=chrome_options)

# %%
table=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td[1]/a")

# %%
filenma=[]
fileti=[]
for i in range(1,len(table)):
    filename=driver.find_element_by_xpath("/html/body/table/tbody/tr["+str(i+1)+"]/td[1]/a")
    print(filename.text)
    filetime=driver.find_element_by_xpath("/html/body/table/tbody/tr["+str(i+1)+"]/td[2]")
    print(filetime.text)
    df = pd.DataFrame({"Filename":filename.text,"File_size":filetime.text}, index=[0])
    
    #df2 = pd.DataFrame({"FileName":filename,"FileTime":filetime},index=[0])
    filenma.append(df)
    #filenma.append(filename.text)
    #fileti.append(filetime.text)
  
    
finaldf = pd.concat(filenma)
finaldf.head()
# Out:
# FullSchedule-(112)-11-11-2021.xml
# 11-11-2021 11:52:02
# FullSchedule-(111)-11-11-2021.xml
# 11-11-2021 11:47:59
# FullSchedule-(2)-12-11-2021.xml
# 11-11-2021 11:39:33
# FullSchedule-(110)-11-11-2021.xml
# 11-11-2021 11:36:46
# FullSchedule-(109)-11-11-2021.xml
# 11-11-2021 11:32:58
# FullSchedule-(108)-11-11-2021.xml
# 11-11-2021 11:21:44
# FullSchedule-(107)-11-11-2021.xml
# 11-11-2021 11:18:04
# FullSchedule-(106)-11-11-2021.xml
# 11-11-2021 11:06:55
# FullSchedule-(105)-11-11-2021.xml
# 11-11-2021 11:02:46
# FullSchedule-(104)-11-11-2021.xml
# 11-11-2021 10:51:59
# FullSchedule-(103)-11-11-2021.xml
# 11-11-2021 10:47:59
# FullSchedule-(102)-11-11-2021.xml
# 11-11-2021 10:37:00
# FullSchedule-(101)-11-11-2021.xml
# 11-11-2021 10:32:44
# FullSchedule-(100)-11-11-2021.xml
# 11-11-2021 10:21:47
# FullSchedule-(99)-11-11-2021.xml
# 11-11-2021 10:18:00
# FullSchedule-(98)-11-11-2021.xml
# 11-11-2021 10:06:49
# FullSchedule-(97)-11-11-2021.xml
# 11-11-2021 10:02:59
# ...

# %% [markdown]
# if "10-01-2021 01:08:00" > "10-01-2021 01:48:00":
#     print("hi")
# else:
#     print("bye")
#
# filenma.append(filename.text)
# fileti.append(filetime.text)

# %%
finaldf.head(5)
# Out:
#                             Filename            File_size
# 0  FullSchedule-(112)-11-11-2021.xml  11-11-2021 11:52:02
# 0  FullSchedule-(111)-11-11-2021.xml  11-11-2021 11:47:59
# 0    FullSchedule-(2)-12-11-2021.xml  11-11-2021 11:39:33
# 0  FullSchedule-(110)-11-11-2021.xml  11-11-2021 11:36:46
# 0  FullSchedule-(109)-11-11-2021.xml  11-11-2021 11:32:58

# %%
import requests
import os

url_new="https://wbes.wrldc.in:81/"

# %% [markdown]
# for i in finaldf['Filename']:
#     #print(i)
#     url="https://wbes.wrldc.in:81/"+i
#     #print(url)
#     response = requests.get(url)
#     #print(response)
#
#     folderpath = r"E:\testdata"
#     filename = os.path.join(folderpath,i)
#
#     print(response.content)
#
#     with open(filename, 'wb') as file:
#         file.write(response.content)
#     print("Done")

# %%
for index, row in finaldf.iterrows():
    print("Downloading Record "+str(row.Filename))
    # print(str(row.Filename))
    url_new="https://wbes.wrldc.in:81/"
    #urllib.request.urlopen(url_new).read().decode('utf-8')
    download_url = url_new + row.Filename
    try:
        response = requests.get(download_url,timeout=None)
    except:
        print("error server")

    folderpath = r"E:\testdata"
    filename = os.path.join(folderpath, row.Filename)

    # print(response.content)

    with open(filename, 'wb') as file:
        file.write(response.content)
    print("Done")
# Out:
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# error server
# Done
# ...
# Done
# ...
# error server
# Done
# ...
# Done
# ...
